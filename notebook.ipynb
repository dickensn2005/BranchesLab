# %% [markdown]
# **Title**

# %% [markdown]
# Author: Nina Dickens

# %%
import numpy as np

# %%
x = np.linspace(0,10,100)

# %%
foo = lambda x:x**2

# %%
y = list(map(foo,x))

# %%
y
# Out:
# [0.0,
#  0.010203040506070809,
#  0.040812162024283234,
#  0.09182736455463729,
#  0.16324864809713294,
#  0.25507601265177027,
#  0.36730945821854916,
#  0.49994898479746963,
#  0.6529945923885317,
#  0.8264462809917354,
#  1.020304050607081,
#  1.234567901234568,
#  1.4692378328741966,
#  1.7243138455259668,
#  1.9997959391898785,
#  2.295684113865932,
#  2.611978369554127,
#  2.9486787062544635,
#  3.305785123966942,
#  3.683297622691562,
#  4.081216202428324,
#  4.499540863177226,
#  4.938271604938272,
#  5.397408427711458,
#  5.8769513314967865,
#  6.376900316294255,
#  6.897255382103867,
#  7.438016528925619,
#  7.999183756759514,
#  8.58075706560555,
#  9.182736455463727,
#  9.805121926334046,
#  10.447913478216508,
#  11.111111111111112,
#  11.794714825017854,
#  12.498724619936741,
#  13.223140495867767,
#  13.967962452810939,
#  14.733190490766248,
#  15.5188246097337,
#  16.324864809713297,
#  17.151311090705025,
#  17.998163452708905,
#  18.865421895724925,
# ...
